# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import pickle

# Load the dataset
data = pd.read_csv('crime__5.csv', usecols=['date_time', 'latitude', 'longitude', 'city', 'state', 'crime_name3'])

# Reduce dataset size by sampling
data = data.sample(n=5000, random_state=42)

# Preprocess date and location inputs
data['date_time'] = pd.to_datetime(data['date_time'])
data['year'] = data['date_time'].dt.year
data['month'] = data['date_time'].dt.month
data['day'] = data['date_time'].dt.day
data['hour'] = data['date_time'].dt.hour
data['minute'] = data['date_time'].dt.minute
data['second'] = data['date_time'].dt.second

# Perform one-hot encoding for categorical variables
cat_cols = ['city', 'state']
enc = OneHotEncoder(drop='first', sparse=False)
encoded_cols = pd.DataFrame(enc.fit_transform(data[cat_cols]))
encoded_cols.columns = enc.get_feature_names(cat_cols)
data.drop(cat_cols, axis=1, inplace=True)
data = pd.concat([data, encoded_cols], axis=1)

# Remove rows with NaN values
data.dropna(subset=['crime_name3'], inplace=True)

# Split the data into training and testing sets
X = data.drop('crime_name3', axis=1)
y = data['crime_name3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Define preprocessing steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# Apply preprocessing to the numeric features
numeric_features = ['year', 'month', 'day', 'hour', 'minute', 'second', 'latitude', 'longitude']
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_features)])

# Append classifier to preprocessing pipeline for Random Forest
rf_model = Pipeline(steps=[('preprocessor', preprocessor),
                           ('classifier', RandomForestClassifier())])

# Fit the Random Forest model
rf_model.fit(X_train, y_train)

# Evaluate the Random Forest model on the test set
rf_pred = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print('Random Forest Classification Report:')
print(classification_report(y_test, rf_pred))
print('Random Forest Accuracy:', rf_accuracy)

# Export the Random Forest model
pickle.dump(rf_model, open('random_forest_model_crime_name3.pkl', 'wb'))

# Append classifier to preprocessing pipeline for SVM
svm_model = Pipeline(steps=[('preprocessor', preprocessor),
                            ('classifier', SVC())])

# Fit the SVM model
svm_model.fit(X_train, y_train)

# Evaluate the SVM model on the test set
svm_pred = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
print('SVM Classification Report:')
print(classification_report(y_test, svm_pred))
print('SVM Accuracy:', svm_accuracy)

# Export the SVM model
pickle.dump(svm_model, open('svm_model_crime_name3.pkl', 'wb'))
# Out:
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Random Forest Classification Report:
#                                                     precision    recall  f1-score   support
#
#                                 ALL OTHER OFFENSES       0.00      0.00      0.00         1
#                                ARSON - RESIDENTIAL       0.00      0.00      0.00         1
#                               ASSAULT - 2ND DEGREE       0.11      0.33      0.17        18
#           ASSAULT - AGGRAVATED - FAMILY-STRONG-ARM       0.00      0.00      0.00         1
#     ASSAULT - AGGRAVATED - NON-FAMILY-OTHER WEAPON       0.00      0.00      0.00         3
#                       ASSAULT - AGGRAVATED - OTHER       0.00      0.00      0.00         0
#         ASSAULT - INTIMIDATION (INCLUDES STALKING)       0.00      0.00      0.00         0
#                                   ASSAULT - SIMPLE       0.00      0.00      0.00         6
#                         AUTO THEFT - VEHICLE THEFT       0.14      0.08      0.11        12
#                        BURGLARY (DESCRIBE OFFENSE)       0.00      0.00      0.00         2
#             BURGLARY - FORCED ENTRY-NONRESIDENTIAL       0.50      0.20      0.29         5
#                BURGLARY - FORCED ENTRY-RESIDENTIAL       0.00      0.00      0.00         7
#          BURGLARY - NO FORCED ENTRY-NONRESIDENTIAL       0.00      0.00      0.00         0
#             BURGLARY - NO FORCED ENTRY-RESIDENTIAL       0.00      0.00      0.00         6
#                                     COUNTERFEITING       0.00      0.00      0.00         0
#                COUNTERFEITING - PASS COUNTERFEITED       0.00      0.00      0.00         1
#                COUNTERFEITING - POSS COUNTERFEITED       0.00      0.00      0.00         0
#                 DAMAGE PROPERTY (DESCRIBE OFFENSE)       0.00      0.00      0.00         4
#                         DAMAGE PROPERTY - BUSINESS       0.00      0.00      0.00         4
#                          DAMAGE PROPERTY - PRIVATE       0.04      0.06      0.05        17
#                           DAMAGE PROPERTY - PUBLIC       0.00      0.00      0.00         1
#                 DRIVING UNDER THE INFLUENCE LIQUOR       0.17      0.20      0.18        10
#                      DRUGS - AMPHETAMINE - POSSESS       0.00      0.00      0.00         1
#                         DRUGS - BARBITURATE - SELL       0.00      0.00      0.00         1
#                          DRUGS - COCAINE - POSSESS       0.00      0.00      0.00         4
#                             DRUGS - COCAINE - SELL       0.00      0.00      0.00         2
#               DRUGS - DANGEROUS (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                     DRUGS - HALLUCINOGEN - POSSESS       0.00      0.00      0.00         1
#                           DRUGS - HEROIN - POSSESS       0.00      0.00      0.00         1
#               DRUGS - MARIJUANA (DESCRIBE OFFENSE)       0.00      0.00      0.00         2
#                        DRUGS - MARIJUANA - POSSESS       0.00      0.00      0.00        13
#                   DRUGS - NARCOTIC EQUIP - POSSESS       0.00      0.00      0.00         5
#     DRUGS - OPIUM OR DERIVATIVE (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#               DRUGS - SYNTHETIC NARCOTIC - POSSESS       0.00      0.00      0.00         0
#                  EXTORT - THREAT INJURE REPUTATION       0.00      0.00      0.00         1
#           FALSE IMPRISONMENT - MINOR - NONPARENTAL       0.00      0.00      0.00         1
# FAMILY OFFENSE - NEGLECT CHILD (INCLUDES NONSUPPOR       0.00      0.00      0.00         1
#                         FORGERY (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                           FORGERY - POSSESS FORGED       0.00      0.00      0.00         1
#                                  FORGERY OF CHECKS       0.00      0.00      0.00         2
#                           FRAUD (DESCRIBE OFFENSE)       0.00      0.00      0.00         3
#                            FRAUD - CONFIDENCE GAME       0.00      0.00      0.00         4
#                   FRAUD - ILLEGAL USE CREDIT CARDS       0.00      0.00      0.00         9
#                              FRAUD - IMPERSONATION       0.00      0.00      0.00         0
#                                    FRAUD - SWINDLE       0.00      0.00      0.00         5
#                                      FRAUD BY WIRE       0.00      0.00      0.00         1
#               FUGITIVE FROM JUSTICE (OUT OF STATE)       0.00      0.00      0.00         0
#                                     IDENTITY THEFT       0.00      0.00      0.00        20
#                                 JUVENILE - RUNAWAY       0.00      0.00      0.00        10
#                         LARCENY (DESCRIBE OFFENSE)       0.00      0.00      0.00        22
#                               LARCENY - AUTO PARTS       0.00      0.00      0.00        18
#                                LARCENY - FROM AUTO       0.13      0.31      0.19        45
#                                LARCENY - FROM BLDG       0.09      0.12      0.10        17
#                        LARCENY - FROM COIN MACHINE       0.00      0.00      0.00         1
#                               LARCENY - FROM YARDS       0.00      0.00      0.00         2
#                           LARCENY - POCKET PICKING       0.00      0.00      0.00         2
#                                   LARCENY - POSTAL       0.00      0.00      0.00         1
#                              LARCENY - SHOPLIFTING       0.21      0.38      0.27        21
#                          LIQUOR (DESCRIBE OFFENSE)       0.00      0.00      0.00         3
#                                   LIQUOR - POSSESS       0.00      0.00      0.00         4
#                                      LOST PROPERTY       0.00      0.00      0.00        21
#                                     MENTAL ILLNESS       0.00      0.00      0.00         5
#                MENTAL ILLNESS - EMERGENCY PETITION       0.03      0.04      0.04        23
#                            MENTAL TRANSPORT - ONLY       0.00      0.00      0.00         1
#                                     MISSING PERSON       0.25      0.09      0.13        11
#                                   OBSCENE MATERIAL       0.00      0.00      0.00         1
#         OBSTRUCT GOVT - VIOLATION OF A COURT ORDER       0.00      0.00      0.00         1
#                                           OVERDOSE       0.00      0.00      0.00         0
#                                 POLICE INFORMATION       0.14      0.19      0.16        37
#                  PUBLIC PEACE - DISORDERLY CONDUCT       0.20      0.09      0.13        11
#             PUBLIC PEACE - HARASSING COMMUNICATION       0.00      0.00      0.00         2
#                                  RAPE - STRONG-ARM       0.00      0.00      0.00         3
#                      RECOVERED PROPERTY - MONT CO.       0.00      0.00      0.00         2
#                         RECOVERED PROPERTY - OTHER       0.00      0.00      0.00         4
#                         ROBBERY (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                             ROBBERY - BUSINESS-GUN       0.00      0.00      0.00         0
#                       ROBBERY - CARJACKING - ARMED       0.00      0.00      0.00         1
#                                 ROBBERY - DOMESTIC       0.00      0.00      0.00         1
#                   ROBBERY - RESIDENTIAL-STRONG-ARM       0.00      0.00      0.00         1
#                               ROBBERY - STREET-GUN       0.00      0.00      0.00         1
#                        ROBBERY - STREET-STRONG-ARM       0.00      0.00      0.00         0
#                               ROBBERY - STRONG ARM       0.00      0.00      0.00         1
#                         SEX ASSAULT - CARNAL ABUSE       0.00      0.00      0.00         1
#                             SEX ASSAULT - FONDLING       0.00      0.00      0.00         3
#               SEX ASSAULT - SODOMY-GIRL-STRONG-ARM       0.00      0.00      0.00         2
# SEX OFFENSE - FAILURE TO REGISTER AS A SEX OFFENDE       1.00      0.50      0.67         4
#                             SEX OFFENSE - FONDLING       0.00      0.00      0.00         1
#           SEX OFFENSE - INDECENT EXPOSURE TO ADULT       0.00      0.00      0.00         2
#                 SMUGGLING - CONTRABAND INTO PRISON       0.00      0.00      0.00         1
#               SOLICITATION - MINOR FOR SEXUAL ACTS       0.00      0.00      0.00         1
#                                       SUDDEN DEATH       0.11      0.09      0.10        11
#                                  SUICIDE - ATTEMPT       0.00      0.00      0.00         3
#                TRAFFIC OFFENSES (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                                        TRESPASSING       0.00      0.00      0.00         6
#  UNAUTHORIZED USE OF VEHICLE (INCLUDES JOY RIDING)       0.00      0.00      0.00         2
#                                 WEAPON - CONCEALED       0.00      0.00      0.00         4
#                                WEAPON - POSSESSION       0.00      0.00      0.00         4
#
#                                           accuracy                           0.10       500
#                                          macro avg       0.03      0.03      0.03       500
#                                       weighted avg       0.07      0.10      0.07       500
#
# Random Forest Accuracy: 0.096
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SVM Classification Report:
#                                                     precision    recall  f1-score   support
#
#                                 ALL OTHER OFFENSES       0.00      0.00      0.00         1
#                                ARSON - RESIDENTIAL       0.00      0.00      0.00         1
#                               ASSAULT - 2ND DEGREE       0.06      0.17      0.09        18
#           ASSAULT - AGGRAVATED - FAMILY-STRONG-ARM       0.00      0.00      0.00         1
#     ASSAULT - AGGRAVATED - NON-FAMILY-OTHER WEAPON       0.00      0.00      0.00         3
#                                   ASSAULT - SIMPLE       0.00      0.00      0.00         6
#                         AUTO THEFT - VEHICLE THEFT       0.00      0.00      0.00        12
#                        BURGLARY (DESCRIBE OFFENSE)       0.00      0.00      0.00         2
#             BURGLARY - FORCED ENTRY-NONRESIDENTIAL       0.00      0.00      0.00         5
#                BURGLARY - FORCED ENTRY-RESIDENTIAL       0.00      0.00      0.00         7
#             BURGLARY - NO FORCED ENTRY-RESIDENTIAL       0.00      0.00      0.00         6
#                COUNTERFEITING - PASS COUNTERFEITED       0.00      0.00      0.00         1
#                 DAMAGE PROPERTY (DESCRIBE OFFENSE)       0.00      0.00      0.00         4
#                         DAMAGE PROPERTY - BUSINESS       0.00      0.00      0.00         4
#                          DAMAGE PROPERTY - PRIVATE       0.00      0.00      0.00        17
#                           DAMAGE PROPERTY - PUBLIC       0.00      0.00      0.00         1
#                 DRIVING UNDER THE INFLUENCE LIQUOR       0.08      0.10      0.09        10
#                      DRUGS - AMPHETAMINE - POSSESS       0.00      0.00      0.00         1
#                         DRUGS - BARBITURATE - SELL       0.00      0.00      0.00         1
#                          DRUGS - COCAINE - POSSESS       0.00      0.00      0.00         4
#                             DRUGS - COCAINE - SELL       0.00      0.00      0.00         2
#               DRUGS - DANGEROUS (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                     DRUGS - HALLUCINOGEN - POSSESS       0.00      0.00      0.00         1
#                           DRUGS - HEROIN - POSSESS       0.00      0.00      0.00         1
#               DRUGS - MARIJUANA (DESCRIBE OFFENSE)       0.00      0.00      0.00         2
#                        DRUGS - MARIJUANA - POSSESS       0.00      0.00      0.00        13
#                   DRUGS - NARCOTIC EQUIP - POSSESS       0.00      0.00      0.00         5
#     DRUGS - OPIUM OR DERIVATIVE (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                  EXTORT - THREAT INJURE REPUTATION       0.00      0.00      0.00         1
#           FALSE IMPRISONMENT - MINOR - NONPARENTAL       0.00      0.00      0.00         1
# FAMILY OFFENSE - NEGLECT CHILD (INCLUDES NONSUPPOR       0.00      0.00      0.00         1
#                         FORGERY (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                           FORGERY - POSSESS FORGED       0.00      0.00      0.00         1
#                                  FORGERY OF CHECKS       0.00      0.00      0.00         2
#                           FRAUD (DESCRIBE OFFENSE)       0.00      0.00      0.00         3
#                            FRAUD - CONFIDENCE GAME       0.00      0.00      0.00         4
#                   FRAUD - ILLEGAL USE CREDIT CARDS       0.00      0.00      0.00         9
#                                    FRAUD - SWINDLE       0.00      0.00      0.00         5
#                                      FRAUD BY WIRE       0.00      0.00      0.00         1
#                                     IDENTITY THEFT       0.00      0.00      0.00        20
#                                 JUVENILE - RUNAWAY       0.00      0.00      0.00        10
#                         LARCENY (DESCRIBE OFFENSE)       0.00      0.00      0.00        22
#                               LARCENY - AUTO PARTS       0.00      0.00      0.00        18
#                                LARCENY - FROM AUTO       0.11      0.82      0.19        45
#                                LARCENY - FROM BLDG       0.00      0.00      0.00        17
#                        LARCENY - FROM COIN MACHINE       0.00      0.00      0.00         1
#                               LARCENY - FROM YARDS       0.00      0.00      0.00         2
#                           LARCENY - POCKET PICKING       0.00      0.00      0.00         2
#                                   LARCENY - POSTAL       0.00      0.00      0.00         1
#                              LARCENY - SHOPLIFTING       0.06      0.19      0.09        21
#                          LIQUOR (DESCRIBE OFFENSE)       0.00      0.00      0.00         3
#                                   LIQUOR - POSSESS       0.00      0.00      0.00         4
#                                      LOST PROPERTY       0.00      0.00      0.00        21
#                                     MENTAL ILLNESS       0.00      0.00      0.00         5
#                MENTAL ILLNESS - EMERGENCY PETITION       0.17      0.09      0.11        23
#                            MENTAL TRANSPORT - ONLY       0.00      0.00      0.00         1
#                                     MISSING PERSON       0.00      0.00      0.00        11
#                                   OBSCENE MATERIAL       0.00      0.00      0.00         1
#         OBSTRUCT GOVT - VIOLATION OF A COURT ORDER       0.00      0.00      0.00         1
#                                 POLICE INFORMATION       0.00      0.00      0.00        37
#                  PUBLIC PEACE - DISORDERLY CONDUCT       0.00      0.00      0.00        11
#             PUBLIC PEACE - HARASSING COMMUNICATION       0.00      0.00      0.00         2
#                                  RAPE - STRONG-ARM       0.00      0.00      0.00         3
#                      RECOVERED PROPERTY - MONT CO.       0.00      0.00      0.00         2
#                         RECOVERED PROPERTY - OTHER       0.00      0.00      0.00         4
#                         ROBBERY (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                       ROBBERY - CARJACKING - ARMED       0.00      0.00      0.00         1
#                                 ROBBERY - DOMESTIC       0.00      0.00      0.00         1
#                   ROBBERY - RESIDENTIAL-STRONG-ARM       0.00      0.00      0.00         1
#                               ROBBERY - STREET-GUN       0.00      0.00      0.00         1
#                               ROBBERY - STRONG ARM       0.00      0.00      0.00         1
#                         SEX ASSAULT - CARNAL ABUSE       0.00      0.00      0.00         1
#                             SEX ASSAULT - FONDLING       0.00      0.00      0.00         3
#               SEX ASSAULT - SODOMY-GIRL-STRONG-ARM       0.00      0.00      0.00         2
# SEX OFFENSE - FAILURE TO REGISTER AS A SEX OFFENDE       0.00      0.00      0.00         4
#                             SEX OFFENSE - FONDLING       0.00      0.00      0.00         1
#           SEX OFFENSE - INDECENT EXPOSURE TO ADULT       0.00      0.00      0.00         2
#                 SMUGGLING - CONTRABAND INTO PRISON       0.00      0.00      0.00         1
#               SOLICITATION - MINOR FOR SEXUAL ACTS       0.00      0.00      0.00         1
#                                       SUDDEN DEATH       0.00      0.00      0.00        11
#                                  SUICIDE - ATTEMPT       0.00      0.00      0.00         3
#                TRAFFIC OFFENSES (DESCRIBE OFFENSE)       0.00      0.00      0.00         1
#                                        TRESPASSING       0.00      0.00      0.00         6
#  UNAUTHORIZED USE OF VEHICLE (INCLUDES JOY RIDING)       0.00      0.00      0.00         2
#                                 WEAPON - CONCEALED       0.00      0.00      0.00         4
#                                WEAPON - POSSESSION       0.00      0.00      0.00         4
#
#                                           accuracy                           0.09       500
#                                          macro avg       0.01      0.02      0.01       500
#                                       weighted avg       0.02      0.09      0.03       500
#
# SVM Accuracy: 0.094
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\GK\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
